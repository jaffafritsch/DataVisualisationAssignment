# %% [markdown]
# # Data Processing and Visualization
# -----
# **Assignment Topic: Data Analysis on Car Advertisements**
#
#
# Student1 Name: Jarrah F.
#
# SNumber: S5212509
#
# Student2 Name: Aditya S.
#
# SNumber: ...
#
# Student3 Name: Grace T.
#
# SNumber: ...

# %% [markdown]
# # Data Import, Tool Import and Variables

# %%
# Tool Import
import pandas, seaborn
import matplotlib.pyplot as plt

# Loads the initial Data sets into variables
dfCarData = pandas.read_csv("car_dataset.csv")
dfSellerData = pandas.read_csv("seller_dataset.csv")

# %% [markdown]
# # Functions

# %%
# First 3 functions are not used anymore but were previously part of my IDE script for testing, kept them in for reference but they are unused
# Prints first 5 rows of each dataset to check they loaded properly
def PrintFirst5():
    print(f"\nFirst 5 Rows of Car Dataset \n{dfCarData.head()}")
    print(f"\nFirst 5 Rows of Seller Dataset \n{dfSellerData.head()}\n\n")

# Function prints the duplicate count for both data sets
def CheckForDuplicates():
    print(f"\nFound {dfCarData.duplicated().sum()} duplicates in the car data")
    print(f"\nFound {dfSellerData.duplicated().sum()} duplicates in the seller data")

# Function prints the null count and columns with null counts + their count for both datasets
def CheckForNulls():
    carDataNullCount = dfCarData.isnull().sum().sum()
    sellerDataNullCount = dfSellerData.isnull().sum().sum()
    print(f"\nFound {carDataNullCount} null values in the car data \n")
    if carDataNullCount > 0:
        nulls = dfCarData.isnull().sum()
        print(nulls[nulls > 0].to_string())
    print(f"\nFound {sellerDataNullCount} null values in the seller data\n")
    if sellerDataNullCount > 0:
        nulls = dfSellerData.isnull().sum()
        print(nulls[nulls > 0].to_string())

# This function does the conversion by iterating through the column, extracting any numbers and then setting 
# The value to the extracted numbers, due to the column having a Dtype of str initially i cast it as object so that it doesnt
# Care what the actual type is then finally cast the column as an int64 - 64 bit integer
# Could have written it as a real function that takes in a dataframe and column name an returns the int but didnt find it
# Necessary for the assignment but would be a better approach if the dataset was variable or wanted a general function for it
def CarNumericalConversion():
    dfCarData["mileage"] = dfCarData["mileage"].astype("object")
    for i, value in dfCarData["mileage"].items():
        convertedNum = "".join(n for n in str(value) if n.isdigit())
        dfCarData.at[i, "mileage"] = int(convertedNum)
    dfCarData["mileage"] = dfCarData["mileage"].astype("Int64")
    dfCarData["num_of_doors"] = dfCarData["num_of_doors"].astype("object")
    for i, value in dfCarData["num_of_doors"].items():
        convertedNum = "".join(n for n in str(value) if n.isdigit())
        dfCarData.at[i, "num_of_doors"] = int(convertedNum)
    dfCarData["num_of_doors"] = dfCarData["num_of_doors"].astype("Int64")
    dfCarData["seating_capacity"] = dfCarData["seating_capacity"].astype("object")
    for i, value in dfCarData["seating_capacity"].items():
        convertedNum = "".join(n for n in str(value) if n.isdigit())
        dfCarData.at[i, "seating_capacity"] = int(convertedNum)
    dfCarData["seating_capacity"] = dfCarData["seating_capacity"].astype("Int64")
    dfCarData["fuel_consumption"] = dfCarData["fuel_consumption"].astype("object")
    for i, value in dfCarData["fuel_consumption"].items():
        convertedNum = "".join(n for n in str(value) if n.isdigit())
        dfCarData.at[i, "fuel_consumption"] = int(convertedNum)
    dfCarData["fuel_consumption"] = dfCarData["fuel_consumption"].astype("Int64")
    print(dfCarData.head())
    dfCarData.info()

def EngineFeatureSplit():
    dfCarData.insert(loc=10, column="type_of_engine", value=None)
    dfCarData.insert(loc=11, column="engine_capacity", value=None)

    for i in dfCarData.index:
        engineValue = dfCarData.at[i, "engine"]
        engineCapacity = "".join(n for n in str(engineValue) if n.isdigit() or n == ".")
        engineCapacity = float(engineCapacity) if engineCapacity else None
        dfCarData.at[i, "engine_capacity"] = engineCapacity
        if str(engineValue).lower().__contains__("petrol"):
            dfCarData.at[i, "type_of_engine"] = "Petrol"
        elif str(engineValue).lower().__contains__("diesel"):
            dfCarData.at[i, "type_of_engine"] = "Diesel"
        elif str(engineValue).lower().__contains__("hybrid"):
            dfCarData.at[i, "type_of_engine"] = "Hybrid"
        elif str(engineValue).lower().__contains__("electric"):
            dfCarData.at[i, "type_of_engine"] = "Electric"
        else:
            dfCarData.at[i, "type_of_engine"] = "Unknown"
    dfCarData["engine_capacity"] = dfCarData["engine_capacity"].astype("float")
    dfCarData["type_of_engine"] = dfCarData["type_of_engine"].astype("str")
    print(dfCarData.head(10))
    dfCarData.info()


def HotEncode():
    # We do a check first to see if the column exists if not create it --> was mainly used during testing to repeatedly run this function and check outputs for ordering otherwise just creating without a check works
    if "origin_code" not in dfCarData.columns:         dfCarData.insert(loc=2, column="origin_code", value=None)
    if "condition_code" not in dfCarData.columns:      dfCarData.insert(loc=4, column="condition_code", value=None)
    if "car_model_code" not in dfCarData.columns:      dfCarData.insert(loc=6, column="car_model_code", value=None)
    if "exterior_color_code" not in dfCarData.columns: dfCarData.insert(loc=9, column="exterior_color_code", value=None)
    if "interior_color_code" not in dfCarData.columns: dfCarData.insert(loc=11, column="interior_color_code", value=None)
    if "type_of_engine_code" not in dfCarData.columns: dfCarData.insert(loc=16, column="type_of_engine_code", value=None)
    if "fuel_system_code" not in dfCarData.columns:    dfCarData.insert(loc=19, column="fuel_system_code", value=None)
    if "transmission_code" not in dfCarData.columns:   dfCarData.insert(loc=21, column="transmission_code", value=None)
    if "drive_type_code" not in dfCarData.columns:     dfCarData.insert(loc=23, column="drive_type_code", value=None)
    if "brand_code" not in dfCarData.columns:          dfCarData.insert(loc=26, column="brand_code", value=None)
    if "grade_code" not in dfCarData.columns:          dfCarData.insert(loc=28, column="grade_code", value=None)

    # We then create the encoded value for each column using pandas functions
    dfCarData["origin_code"] = dfCarData["origin"].astype("category").cat.codes
    dfCarData["condition_code"] = dfCarData["condition"].astype("category").cat.codes
    dfCarData["car_model_code"] = dfCarData["car_model"].astype("category").cat.codes
    dfCarData["exterior_color_code"] = dfCarData["exterior_color"].astype("category").cat.codes
    dfCarData["interior_color_code"] = dfCarData["interior_color"].astype("category").cat.codes
    dfCarData["type_of_engine_code"] = dfCarData["type_of_engine"].astype("category").cat.codes
    dfCarData["fuel_system_code"] = dfCarData["fuel_system"].astype("category").cat.codes
    dfCarData["transmission_code"] = dfCarData["transmission"].astype("category").cat.codes
    dfCarData["drive_type_code"] = dfCarData["drive_type"].astype("category").cat.codes
    dfCarData["brand_code"] = dfCarData["brand"].astype("category").cat.codes
    dfCarData["grade_code"] = dfCarData["grade"].astype("category").cat.codes

    # we then create dicts to map these values so we can convert between the code and label
    origin_decoder = dfCarData[["origin_code", "origin"]].drop_duplicates().set_index("origin_code")["origin"].to_dict()
    condition_decoder = dfCarData[["condition_code", "condition"]].drop_duplicates().set_index("condition_code")["condition"].to_dict()
    model_decoder = dfCarData[["car_model_code", "car_model"]].drop_duplicates().set_index("car_model_code")["car_model"].to_dict()
    exterior_color_decoder = dfCarData[["exterior_color_code", "exterior_color"]].drop_duplicates().set_index("exterior_color_code")["exterior_color"].to_dict()
    interior_color_decoder = dfCarData[["interior_color_code", "interior_color"]].drop_duplicates().set_index("interior_color_code")["interior_color"].to_dict()
    engine_type_decoder = dfCarData[["type_of_engine_code", "type_of_engine"]].drop_duplicates().set_index("type_of_engine_code")["type_of_engine"].to_dict()
    fuel_system_decoder = dfCarData[["fuel_system_code", "fuel_system"]].drop_duplicates().set_index("fuel_system_code")["fuel_system"].to_dict()
    transmission_decoder = dfCarData[["transmission_code", "transmission"]].drop_duplicates().set_index("transmission_code")["transmission"].to_dict()
    drive_decoder = dfCarData[["drive_type_code", "drive_type"]].drop_duplicates().set_index("drive_type_code")["drive_type"].to_dict()
    brand_decoder = dfCarData[["brand_code", "brand"]].drop_duplicates().set_index("brand_code")["brand"].to_dict()
    grade_decoder = dfCarData[["grade_code", "grade"]].drop_duplicates().set_index("grade_code")["grade"].to_dict()

    # Print all the decoders for reference
    print(f"Origin Decoder \n {dict(sorted(origin_decoder.items()))}")
    print(f"Condition Decoder \n {dict(sorted(condition_decoder.items()))}")
    print(f"Model Decoder \n {dict(sorted(model_decoder.items()))}")
    print(f"Exteriror Color Decoder \n {dict(sorted(exterior_color_decoder.items()))}")
    print(f"Interiror Color Decoder \n {dict(sorted(interior_color_decoder.items()))}")
    print(f"Engine Type Decoder \n {dict(sorted(engine_type_decoder.items()))}")
    print(f"Fuel System Decoder \n {dict(sorted(fuel_system_decoder.items()))}")
    print(f"Transmission Decoder \n {dict(sorted(transmission_decoder.items()))}")
    print(f"Drive Decoder \n {dict(sorted(drive_decoder.items()))}")
    print(f"Brand Decoder \n {dict(sorted(brand_decoder.items()))}")
    print(f"Grade Decoder \n {dict(sorted(grade_decoder.items()))}")

    # Print a sample of the data plus the dataframe info
    print(dfCarData.head(10))
    dfCarData.info()



def StandardiseText():
    for col in dfCarData.select_dtypes(include=["string"]).columns:
        dfCarData[col] = dfCarData[col].str.lower()
    print(dfCarData.head(10))
    dfCarData.info()


def NormaliseNumericalValues():
    columns = ["engine_capacity", "num_of_doors", "seating_capacity", "fuel_consumption", "price"]
    
    for col in columns:
        min_val = dfCarData[str(col)].min()
        max_val = dfCarData[str(col)].max()
        columName = col + "_minmax"
        dfCarData["doors_minmax"] = (dfCarData["num_of_doors"] - min_val) / (max_val - min_val)

# %% [markdown]
# # Data Formatting

# %% [markdown]
# ## 1A

# %%
CarNumericalConversion()
# Out:
#    ad_id             origin condition  car_model  mileage exterior_color interior_color  num_of_doors  seating_capacity         engine fuel_system transmission                 drive_type  fuel_consumption   brand              grade  year_of_manufacture                              car_name   price (AUD)
# 0  17042  Domestic assembly   New car      Truck        0          White           gray             2                 2  Petrol\t1.0 L         NaN       Manual     RFD - Rear-wheel drive               100  Suzuki  Super Carry Truck               2022.0  Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1  53794           Imported   New car        SUV        0          Black          Black             5                 7  Petrol\t3.4 L         NaN    Automatic  AWD - 4-wheel drive (AWD)             10100  Toyota       Land Cruiser               2022.0       Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2  73954  Domestic assembly   New car  Crossover        0         Silver          Brown             5                 8  Petrol\t2.0 L         NaN    Automatic     RFD - Rear-wheel drive               100  Toyota             Innova               2023.0       Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3  74150           Imported   New car        SUV        0          White          Black             5                 5  Petrol\t1.8 L         NaN    Automatic    FWD - Front-wheel drive               100  Toyota      Corolla Cross               2023.0        Toyota Corolla Cross 1.8G 2023   30526.38376
# 4  87573  Domestic assembly   New car  Crossover        0         Silver           gray             5                 8  Petrol\t2.0 L         NaN    Automatic     RFD - Rear-wheel drive               100  Toyota             Innova               2022.0       Toyota Innova G 2.0 AT 2022 car   34413.03209
# <class 'pandas.DataFrame'>
# RangeIndex: 30652 entries, 0 to 30651
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                30652 non-null  int64
#  1   origin               30652 non-null  str
#  2   condition            30652 non-null  str
#  3   car_model            30652 non-null  str
#  4   mileage              30652 non-null  Int64
#  5   exterior_color       30652 non-null  str
#  6   interior_color       30652 non-null  str
#  7   num_of_doors         30652 non-null  Int64
#  8   seating_capacity     30652 non-null  Int64
#  9   engine               30652 non-null  str
#  10  fuel_system          6742 non-null   str
#  11  transmission         30652 non-null  str
#  12  drive_type           30652 non-null  str
#  13  fuel_consumption     30652 non-null  Int64
#  14  brand                30652 non-null  str
#  15  grade                30652 non-null  str
#  16  year_of_manufacture  30620 non-null  float64
#  17  car_name             30652 non-null  str
#  18  price (AUD)          30652 non-null  float64
# dtypes: Int64(4), float64(2), int64(1), str(12)
# memory usage: 4.6 MB

# %% [markdown]
# ## 1B

# %%
EngineFeatureSplit()
# Out:
#     ad_id             origin condition    car_model  mileage exterior_color interior_color  num_of_doors  seating_capacity         engine type_of_engine  engine_capacity                 fuel_system transmission                    drive_type  fuel_consumption   brand              grade  year_of_manufacture                               car_name   price (AUD)
# 0   17042  Domestic assembly   New car        Truck        0          White           gray             2                 2  Petrol\t1.0 L         Petrol              1.0                         NaN       Manual        RFD - Rear-wheel drive               100  Suzuki  Super Carry Truck               2022.0   Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1   53794           Imported   New car          SUV        0          Black          Black             5                 7  Petrol\t3.4 L         Petrol              3.4                         NaN    Automatic     AWD - 4-wheel drive (AWD)             10100  Toyota       Land Cruiser               2022.0        Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2   73954  Domestic assembly   New car    Crossover        0         Silver          Brown             5                 8  Petrol\t2.0 L         Petrol              2.0                         NaN    Automatic        RFD - Rear-wheel drive               100  Toyota             Innova               2023.0        Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3   74150           Imported   New car          SUV        0          White          Black             5                 5  Petrol\t1.8 L         Petrol              1.8                         NaN    Automatic       FWD - Front-wheel drive               100  Toyota      Corolla Cross               2023.0         Toyota Corolla Cross 1.8G 2023   30526.38376
# 4   87573  Domestic assembly   New car    Crossover        0         Silver           gray             5                 8  Petrol\t2.0 L         Petrol              2.0                         NaN    Automatic        RFD - Rear-wheel drive               100  Toyota             Innova               2022.0        Toyota Innova G 2.0 AT 2022 car   34413.03209
# 5   97011  Domestic assembly   New car  Van/Minivan        0          White           gray             5                 2  Petrol\t1.0 L         Petrol              1.0                         NaN       Manual        RFD - Rear-wheel drive              7100  Suzuki    Super Carry Van               2023.0  Suzuki Super Carry Van Blind Van 2023   12105.29011
# 6  101726  Domestic assembly   New car          SUV        0          White          Black             5                 7  Petrol\t1.5 L         Petrol              1.5                         NaN    Automatic       FWD - Front-wheel drive               100   Honda                CRV               2023.0                   Honda CRV L 2023 car   39838.14539
# 7  135739           Imported   New car          SUV        0         Copper          Black             5                 7  Petrol\t2.7 L         Petrol              2.7                         NaN    Automatic        RFD - Rear-wheel drive               100  Toyota           Fortuner               2023.0       Toyota Fortuner 2.7L 4x2 AT 2023   40485.92011
# 8  142495  Domestic assembly   New car          4x4        0           Grey          Black             4                 5  Diesel\t2.2 L         Diesel              2.2  Single turbo oil injection    Automatic        RFD - Rear-wheel drive              7100    Ford             Ranger               2023.0       Ford Ranger XLS 2.0L 4x2 AT 2023   27854.31303
# 9  143308  Domestic assembly   New car          4x4        0          Black          Black             4                 5  Diesel\t2.2 L         Diesel              2.2  Single turbo oil injection    Automatic  4WD - Four-wheel drive (4WD)              7100    Ford             Ranger               2023.0       Ford Ranger XLT 2.0L 4x4 AT 2023   33603.31369
# <class 'pandas.DataFrame'>
# RangeIndex: 30652 entries, 0 to 30651
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                30652 non-null  int64
#  1   origin               30652 non-null  str
#  2   condition            30652 non-null  str
#  3   car_model            30652 non-null  str
#  4   mileage              30652 non-null  Int64
#  5   exterior_color       30652 non-null  str
#  6   interior_color       30652 non-null  str
#  7   num_of_doors         30652 non-null  Int64
#  8   seating_capacity     30652 non-null  Int64
#  9   engine               30652 non-null  str
#  10  type_of_engine       30652 non-null  str
#  11  engine_capacity      29285 non-null  float64
#  12  fuel_system          6742 non-null   str
#  13  transmission         30652 non-null  str
#  14  drive_type           30652 non-null  str
#  15  fuel_consumption     30652 non-null  Int64
#  16  brand                30652 non-null  str
#  17  grade                30652 non-null  str
#  18  year_of_manufacture  30620 non-null  float64
#  19  car_name             30652 non-null  str
#  20  price (AUD)          30652 non-null  float64
# dtypes: Int64(4), float64(3), int64(1), str(13)
# memory usage: 5.0 MB

# %% [markdown]
# ## 1C

# %%
HotEncode()
# Out:
# Origin Decoder
#  {0: 'Domestic assembly', 1: 'Imported'}
# Condition Decoder
#  {0: 'New car', 1: 'Used car'}
# Model Decoder
#  {0: '4x4', 1: 'Convertible/Cabriolet', 2: 'Coupe', 3: 'Crossover', 4: 'Hatchback', 5: 'SUV', 6: 'Sedan', 7: 'Truck', 8: 'Van/Minivan', 9: 'Wagon'}
# Exteriror Color Decoder
#  {0: '-', 1: 'Black', 2: 'Brown', 3: 'Colorful', 4: 'Copper', 5: 'Cream', 6: 'Different color', 7: 'Green', 8: 'Grey', 9: 'Orange', 10: 'Pink', 11: 'Red', 12: 'Sand', 13: 'Silver', 14: 'Take note', 15: 'Violet', 16: 'White', 17: 'Yellow'}
# Interiror Color Decoder
#  {0: '-', 1: 'Black', 2: 'Brown', 3: 'Colorful', 4: 'Copper', 5: 'Cream', 6: 'Different color', 7: 'Green', 8: 'Grey', 9: 'Orange', 10: 'Pink', 11: 'Red', 12: 'Sand', 13: 'Silver', 14: 'Violet', 15: 'White', 16: 'Yellow', 17: 'gray'}
# Engine Type Decoder
#  {0: 'Diesel', 1: 'Electric', 2: 'Hybrid', 3: 'Petrol', 4: 'Unknown'}
# Fuel System Decoder
#  {-1: nan, 0: ' 1.5L', 1: ' 2.0 turbo', 2: ' 2.0L i4 TDCi Bi-Turbo Diesel engine', 3: ' 2.4LE', 4: ' 4M40 diesel', 5: ' 5l', 6: ' Automatic', 7: ' Axial Spraying', 8: ' Bec Dau Dien', 9: ' Bec co', 10: ' Bom-tubo-', 11: ' CDI', 12: ' CVT', 13: ' Carburetor', 14: ' Che', 15: ' Common Rail electronic oil injection', 16: ' Crazy man', 17: ' DOHC', 18: ' Diesel', 19: ' Direct', 20: ' Direct Spray', 21: ' Direct fuel injection', 22: ' Direct spray', 23: ' Disel', 24: ' EFI', 25: ' ELECTRONIC', 26: ' EcoBoost', 27: ' Electric fuel injection', 28: ' Electric fuel injector', 29: ' Electric pump', 30: ' Electricity', 31: ' Electronic', 32: ' Electronic Fuel Injection', 33: ' Electronic fuel injection', 34: ' Electronic fuel injection tubo', 35: ' Electronic fuel injector', 36: ' Electronic fun', 37: ' Electronic injector', 38: ' Electronic oil injection', 39: ' Electronic spraying', 40: ' Electronic tube', 41: ' Electrostatic spraying', 42: ' Face death', 43: ' Fi', 44: ' Fuel injection', 45: ' Full', 46: ' Full electronic gasoline', 47: ' Full electronic needle', 48: ' Full electronic pliers', 49: ' Full electronics', 50: ' Fun NL electronics', 51: ' Fun electronic gasoline', 52: ' Fun gasoline', 53: ' Gas tank', 54: ' Gasoline', 55: ' Gasoline + Electricity', 56: ' Good', 57: ' Have', 58: ' I4 2.0', 59: ' Indirect', 60: ' Injector', 61: ' Kim ful', 62: ' Kim ful electronic', 63: ' Kim full', 64: ' Load', 65: ' M', 66: ' MIVEC', 67: ' Mechanism', 68: ' Multi-point fuel injection', 69: ' Multi-point spraying', 70: ' Muscle', 71: ' Naturally Aspirated', 72: ' Naturally aspirated', 73: ' Nature', 74: ' Nature Air', 75: ' Oil', 76: ' Phu', 77: ' Pump', 78: ' Rice', 79: ' Spray', 80: ' Spray oil', 81: ' Strawberry', 82: ' TD', 83: ' Tel', 84: ' Tu dong', 85: ' Tubo', 86: ' Tubo electronic fuel injection', 87: ' Tubor', 88: ' Turbo Booster', 89: ' Turbocharger', 90: ' Turbocharger (turbo)', 91: ' Turbocharger Saves Fuel', 92: ' VVT', 93: ' VVTI', 94: ' Vvti', 95: ' Where', 96: ' Xang', 97: ' charging station', 98: ' direct', 99: ' electronic', 100: ' electronic fuel injection', 101: ' fuel injection', 102: ' gasoline', 103: ' injector', 104: ' jar', 105: ' phudientu', 106: ' spray', 107: '-', 108: '.', 109: '...', 110: '0', 111: '1', 112: '1.0 AT', 113: '1.0 Turbo', 114: '1.0 Turbocharged', 115: '1.0L', 116: '1.1', 117: '1.2', 118: '1.25L', 119: '1.2L', 120: '1.3', 121: '1.3L', 122: '1.4', 123: '1.4L', 124: '1.4l', 125: '1.5', 126: '1.5 AT', 127: '1.5 naturally aspirated', 128: '1.5 tubor', 129: '1.5 turbo', 130: '1.5G', 131: '1.5L', 132: '1.5l', 133: '1.6', 134: '1.6 L', 135: '1.6 Turbo', 136: '1.6 turbo', 137: '1.6L', 138: '1.8', 139: '1.8 AT', 140: '1.8G', 141: '1.8L', 142: '10 liters', 143: '100', 144: '100l', 145: '11', 146: '11 liters', 147: '13', 148: '2', 149: '2 at', 150: '2.0 Bi-Turbo', 151: '2.0 L', 152: '2.0 Tuber', 153: '2.0 Turbo', 154: '2.0 turbo', 155: '2.0L', 156: '2.0L gasoline', 157: '2.0L turbo ball', 158: '2.0Tfsi', 159: '2.0Tubor', 160: '2.0l', 161: '2.2', 162: '2.2L', 163: '2.2d', 164: '2.2l', 165: '2.3', 166: '2.3L', 167: '2.3L Turbo', 168: '2.4', 169: '2.4 GL', 170: '2.4 MIVEC', 171: '2.4G', 172: '2.4L', 173: '2.5', 174: '2.5 liters', 175: '2.5L', 176: '2.5l', 177: '2.7', 178: '2.7 DuraVVTi', 179: '2.7L', 180: '2.9', 181: '3', 182: '3.0 turbo', 183: '3.0L', 184: '3.0L gasoline', 185: '3.2 turbo', 186: '3.2L oil', 187: '3.3', 188: '3.3 LE', 189: '3.3L gasoline', 190: '3.5', 191: '3.5L', 192: '3.5L V6', 193: '3.5L V6 Twin-Turbo', 194: '3.5L gasoline', 195: '3.6', 196: '3.6 V8', 197: '3.6 tubes', 198: '3.7 V6', 199: '37', 200: '4', 201: '4 cylinders', 202: '4 machines', 203: '4.6', 204: '4.7L', 205: '40', 206: '42', 207: '4B12 DOHC MIVEC', 208: '5', 209: '5 liters', 210: '5.2', 211: '5.5', 212: '5.7', 213: '5.7L', 214: '5/100km', 215: '50', 216: '53', 217: '55', 218: '55l', 219: '5l/100km', 220: '6', 221: '6.5', 222: '6.5 liters', 223: '6.75', 224: '60', 225: '65', 226: '6L/100km', 227: '7', 228: '7 liters', 229: '70', ...
# Transmission Decoder
#  {0: '-', 1: 'Automatic', 2: 'Hybrid', 3: 'Manual'}
# Drive Decoder
#  {0: '-', 1: '4WD - Four-wheel drive (4WD)', 2: '4WD or AWD', 3: 'AWD - 4-wheel drive (AWD)', 4: 'FWD - Front-wheel drive', 5: 'RFD - Rear-wheel drive'}
# Brand Decoder
#  {0: 'Acura', 1: 'Aston Martin', 2: 'Audi', 3: 'BMW', 4: 'BYD', 5: 'Baic', 6: 'Bentley', 7: 'Brilliance', 8: 'Buick', 9: 'Cadillac', 10: 'Changan', 11: 'Chery', 12: 'Chevrolet', 13: 'Chrysler', 14: 'Citroen', 15: 'Daewoo', 16: 'Daihatsu', 17: 'Dodge', 18: 'Dongben', 19: 'Dongfeng', 20: 'Ferrari', 21: 'Fiat', 22: 'Ford', 23: 'GMC', 24: 'Gaz', 25: 'Geely', 26: 'Hino', 27: 'Honda', 28: 'Hongqi', 29: 'Hummer', 30: 'Hyundai', 31: 'Infiniti', 32: 'Isuzu', 33: 'JRD', 34: 'Jaguar', 35: 'Jeep', 36: 'Kia', 37: 'Lamborghini', 38: 'LandRover', 39: 'Lexus', 40: 'Lifan', 41: 'Lincoln', 42: 'Luxgen', 43: 'MG', 44: 'Maserati', 45: 'Mazda', 46: 'McLaren', 47: 'Mekong', 48: 'Mercedes Benz', 49: 'Mini', 50: 'Mitsubishi', 51: 'Nissan', 52: 'Peugeot', 53: 'Pontiac', 54: 'Porsche', 55: 'Proton', 56: 'RAM', 57: 'Renault', 58: 'Rolls Royce', 59: 'SYM', 60: 'Samsung', 61: 'Scion', 62: 'Smart', 63: 'Ssangyong', 64: 'Subaru', 65: 'Suzuki', 66: 'Tesla', 67: 'Thaco', 68: 'Tobe', 69: 'Toyota', 70: 'UAZ', 71: 'VinFast', 72: 'Vinaxuki', 73: 'Volkswagen', 74: 'Volvo', 75: 'Zotye'}
# Grade Decoder
#  {0: '1 Series', 1: '107', 2: '1500', 3: '1980T', 4: '2', 5: '2 Series', 6: '2008', 7: '208', 8: '3', 9: '3 Series', 10: '300 Series', 11: '3008', 12: '300C', 13: '320', 14: '323', 15: '3308', 16: '4 Runner', 17: '4 Series', 18: '405', 19: '408', 20: '488', 21: '5', 22: '5 Series', 23: '500', 24: '500 Series', 25: '5008', 26: '508', 27: '520', 28: '6', 29: '6 Series', 30: '605', 31: '626', 32: '650s', 33: '7 Series', 34: '718', 35: '720S', 36: '765LT', 37: '86', 38: '911', 39: '990T', 40: 'A class', 41: 'A1', 42: 'A3', 43: 'A4', 44: 'A5', 45: 'A6', 46: 'A7', 47: 'A8', 48: 'AMG GT', 49: 'APV', 50: 'Accent', 51: 'Accord', 52: 'Albea', 53: 'Almera', 54: 'Alphard', 55: 'Alto', 56: 'Attrage', 57: 'Auman', 58: 'Aumark', 59: 'Avalon', 60: 'Avante', 61: 'Avanza', 62: 'Aventador', 63: 'Aveo', 64: 'Aygo', 65: 'BRZ', 66: 'BT50', 67: 'Baleno', 68: 'Beetle', 69: 'Beijing X7', 70: 'Bentayga', 71: 'Bluebird', 72: 'Bongo', 73: 'Boxster', 74: 'Brio', 75: 'C class', 76: 'CL', 77: 'CLA class', 78: 'CLK class', 79: 'CLS class', 80: 'CRV', 81: 'CX 30', 82: 'CX20', 83: 'CX5', 84: 'CX7', 85: 'CX8', 86: 'CX9', 87: 'California', 88: 'Camaro', 89: 'Camry', 90: 'Canter', 91: 'Captiva', 92: 'Caravan', 93: 'Carens', 94: 'Carnival', 95: 'Carry', 96: 'Cayenne', 97: 'Cedric', 98: 'Cefiro', 99: 'Celerio', 100: 'Celica', 101: 'Cerato', 102: 'Ciaz', 103: 'Citivan', 104: 'City', 105: 'Civic', 106: 'Click', 107: 'Colorado', 108: 'Colt', 109: 'Continental', 110: 'Cooper', 111: 'Corolla', 112: 'Corolla Cross', 113: 'Corolla altis', 114: 'Corona', 115: 'County', 116: 'Cressida', 117: 'Creta', 118: 'Crown', 119: 'Cruze', 120: 'Cullinan', 121: 'DB X30', 122: 'DB1021', 123: 'DS3', 124: 'Daily', 125: 'Defender', 126: 'Discovery', 127: 'Discovery Sport', 128: 'Dmax', 129: 'Doblo', 130: 'Duster', 131: 'E class', 132: 'E-HS9', 133: 'E-tron GT', 134: 'EQS', 135: 'ES', 136: 'EX', 137: 'EcoSport', 138: 'Elantra', 139: 'Emgrand', 140: 'Eon', 141: 'Equus', 142: 'Ertiga', 143: 'Escalade', 144: 'Escape', 145: 'Espero', 146: 'Everest', 147: 'Explorer', 148: 'Express', 149: 'F-Pace', 150: 'F0', 151: 'F150', 152: 'F350', 153: 'F6', 154: 'F8', 155: 'FVR', 156: 'FX', 157: 'Fadil', 158: 'Feroza', 159: 'Fiesta', 160: 'Flying Spur', 161: 'Focus', 162: 'Forester', 163: 'Forfour', 164: 'Forland', 165: 'Forte', 166: 'Fortuner', 167: 'Fortwo', 168: 'Foton', 169: 'Freelander', 170: 'Frontier', 171: 'G class', 172: 'G35', 173: 'G37', 174: 'GL', 175: 'GLA class', 176: 'GLB', 177: 'GLC', 178: 'GLE Class', 179: 'GLK Class', 180: 'GLS', 181: 'GS', 182: 'GX', 183: 'Galloper', 184: 'Gazele', 185: 'Genesis', 186: 'Gentra', 187: 'GentraX', 188: 'Getz', 189: 'Ghibli', 190: 'Ghost', 191: 'Gladiator', 192: 'Grace', 193: 'GranCabrio', 194: 'GranTurismo', 195: 'Grand Starex', 196: 'Grand cherokee', 197: 'Grand livina', 198: 'Grand vitara', 199: 'Grandeur', 200: 'Grandis', 201: 'Grunder', 202: 'H 1', 203: 'H 100', 204: 'H2', 205: 'H9', 206: 'HD', 207: 'HRV', 208: 'HS', 209: 'Hi lander', 210: 'Hiace', 211: 'Highlander', 212: 'Hijet', 213: 'Hilux', 214: 'Hunter', 215: 'Huracan', 216: 'IS', 217: 'Innova', 218: 'Jazz', 219: 'Jinbei', 220: 'Jolie', 221: 'Juke', 222: 'K2700', 223: 'K3', 224: 'K3000S', 225: 'K5', 226: 'Khác', 227: 'Kicks', 228: 'Koleos', 229: 'Kona', 230: 'Korando', 231: 'L300', 232: 'LC', 233: 'LM', 234: 'LS', 235: 'LX', 236: 'LaCrosse', 237: 'Labo', 238: 'Lacetti', 239: 'Lancer', 240: 'Land Cruiser', 241: 'Lanos', 242: 'Laser', 243: 'Latitude', 244: 'Leganza', 245: 'Levante', 246: 'Libero', 247: 'Livina', 248: 'Lux A 2.0', 249: 'Lux SA 2.0', 250: 'M4', 251: 'M5', 252: 'M7', 253: 'MB', 254: 'MC20', 255: 'MDX', 256: 'ML Class', 257: 'MU-X', 258: 'Macan', 259: 'Magnus', 260: 'Matiz', 261: 'Maxima', 262: 'Maybach', 263: 'Mcar', 264: 'Megane', 265: 'Micra', 266: 'Mighty', 267: 'Mirage', 268: 'Mobihome', 269: 'Mondeo', 270: 'Montero', 271: 'Morning', 272: 'Mulsanne', 273: 'Murano', 274: 'Musso', 275: 'Mustang', 276: 'NLR', 277: 'NMR', 278: 'NPR', 279: 'NQR', 280: 'NX', 281: 'Navara', 282: 'Navigator', ...
#     ad_id             origin  origin_code condition  condition_code    car_model  car_model_code  mileage exterior_color  exterior_color_code interior_color  interior_color_code  num_of_doors  seating_capacity         engine type_of_engine  type_of_engine_code  engine_capacity                 fuel_system  fuel_system_code transmission  transmission_code                    drive_type  drive_type_code  fuel_consumption   brand  brand_code              grade  grade_code  year_of_manufacture                               car_name   price (AUD)
# 0   17042  Domestic assembly            0   New car               0        Truck               7        0          White                   16           gray                   17             2                 2  Petrol\t1.0 L         Petrol                    3              1.0                         NaN                -1       Manual                  3        RFD - Rear-wheel drive                5               100  Suzuki          65  Super Carry Truck         384               2022.0   Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1   53794           Imported            1   New car               0          SUV               5        0          Black                    1          Black                    1             5                 7  Petrol\t3.4 L         Petrol                    3              3.4                         NaN                -1    Automatic                  1     AWD - 4-wheel drive (AWD)                3             10100  Toyota          69       Land Cruiser         240               2022.0        Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2   73954  Domestic assembly            0   New car               0    Crossover               3        0         Silver                   13          Brown                    2             5                 8  Petrol\t2.0 L         Petrol                    3              2.0                         NaN                -1    Automatic                  1        RFD - Rear-wheel drive                5               100  Toyota          69             Innova         217               2023.0        Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3   74150           Imported            1   New car               0          SUV               5        0          White                   16          Black                    1             5                 5  Petrol\t1.8 L         Petrol                    3              1.8                         NaN                -1    Automatic                  1       FWD - Front-wheel drive                4               100  Toyota          69      Corolla Cross         112               2023.0         Toyota Corolla Cross 1.8G 2023   30526.38376
# 4   87573  Domestic assembly            0   New car               0    Crossover               3        0         Silver                   13           gray                   17             5                 8  Petrol\t2.0 L         Petrol                    3              2.0                         NaN                -1    Automatic                  1        RFD - Rear-wheel drive                5               100  Toyota          69             Innova         217               2022.0        Toyota Innova G 2.0 AT 2022 car   34413.03209
# 5   97011  Domestic assembly            0   New car               0  Van/Minivan               8        0          White                   16           gray                   17             5                 2  Petrol\t1.0 L         Petrol                    3              1.0                         NaN                -1       Manual                  3        RFD - Rear-wheel drive                5              7100  Suzuki          65    Super Carry Van         385               2023.0  Suzuki Super Carry Van Blind Van 2023   12105.29011
# 6  101726  Domestic assembly            0   New car               0          SUV               5        0          White                   16          Black                    1             5                 7  Petrol\t1.5 L         Petrol                    3              1.5                         NaN                -1    Automatic                  1       FWD - Front-wheel drive                4               100   Honda          27                CRV          80               2023.0                   Honda CRV L 2023 car   39838.14539
# 7  135739           Imported            1   New car               0          SUV               5        0         Copper                    4          Black                    1             5                 7  Petrol\t2.7 L         Petrol                    3              2.7                         NaN                -1    Automatic                  1        RFD - Rear-wheel drive                5               100  Toyota          69           Fortuner         166               2023.0       Toyota Fortuner 2.7L 4x2 AT 2023   40485.92011
# 8  142495  Domestic assembly            0   New car               0          4x4               0        0           Grey                    8          Black                    1             4                 5  Diesel\t2.2 L         Diesel                    0              2.2  Single turbo oil injection               583    Automatic                  1        RFD - Rear-wheel drive                5              7100    Ford          22             Ranger         336               2023.0       Ford Ranger XLS 2.0L 4x2 AT 2023   27854.31303
# 9  143308  Domestic assembly            0   New car               0          4x4               0        0          Black                    1          Black                    1             4                 5  Diesel\t2.2 L         Diesel                    0              2.2  Single turbo oil injection               583    Automatic                  1  4WD - Four-wheel drive (4WD)                1              7100    Ford          22             Ranger         336               2023.0       Ford Ranger XLT 2.0L 4x4 AT 2023   33603.31369
# <class 'pandas.DataFrame'>
# RangeIndex: 30652 entries, 0 to 30651
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                30652 non-null  int64
#  1   origin               30652 non-null  str
#  2   origin_code          30652 non-null  int8
#  3   condition            30652 non-null  str
#  4   condition_code       30652 non-null  int8
#  5   car_model            30652 non-null  str
#  6   car_model_code       30652 non-null  int8
#  7   mileage              30652 non-null  Int64
#  8   exterior_color       30652 non-null  str
#  9   exterior_color_code  30652 non-null  int8
#  10  interior_color       30652 non-null  str
#  11  interior_color_code  30652 non-null  int8
#  12  num_of_doors         30652 non-null  Int64
#  13  seating_capacity     30652 non-null  Int64
#  14  engine               30652 non-null  str
#  15  type_of_engine       30652 non-null  str
#  16  type_of_engine_code  30652 non-null  int8
#  17  engine_capacity      29285 non-null  float64
#  18  fuel_system          6742 non-null   str
#  19  fuel_system_code     30652 non-null  int16
#  20  transmission         30652 non-null  str
#  21  transmission_code    30652 non-null  int8
#  22  drive_type           30652 non-null  str
#  23  drive_type_code      30652 non-null  int8
#  24  fuel_consumption     30652 non-null  Int64
#  25  brand                30652 non-null  str
#  26  brand_code           30652 non-null  int8
#  27  grade                30652 non-null  str
#  28  grade_code           30652 non-null  int16
#  29  year_of_manufacture  30620 non-null  float64
#  30  car_name             30652 non-null  str
#  31  price (AUD)          30652 non-null  float64
# dtypes: Int64(4), float64(3), int16(2), int64(1), int8(9), str(13)
# memory usage: 5.4 MB

# %% [markdown]
# ## 1D

# %%
StandardiseText()
# Out:
#     ad_id             origin  origin_code condition  condition_code    car_model  car_model_code  mileage exterior_color  exterior_color_code interior_color  interior_color_code  num_of_doors  seating_capacity         engine type_of_engine  type_of_engine_code  engine_capacity                 fuel_system  fuel_system_code transmission  transmission_code                    drive_type  drive_type_code  fuel_consumption   brand  brand_code              grade  grade_code  year_of_manufacture                               car_name   price (AUD)
# 0   17042  domestic assembly            0   new car               0        truck               7        0          white                   16           gray                   17             2                 2  petrol\t1.0 l         petrol                    3              1.0                         NaN                -1       manual                  3        rfd - rear-wheel drive                5               100  suzuki          65  super carry truck         384               2022.0   suzuki super carry truck 1.0 mt 2022   10080.99411
# 1   53794           imported            1   new car               0          suv               5        0          black                    1          black                    1             5                 7  petrol\t3.4 l         petrol                    3              3.4                         NaN                -1    automatic                  1     awd - 4-wheel drive (awd)                3             10100  toyota          69       land cruiser         240               2022.0        toyota land cruiser 3.5 v6 2022  161943.68050
# 2   73954  domestic assembly            0   new car               0    crossover               3        0         silver                   13          brown                    2             5                 8  petrol\t2.0 l         petrol                    3              2.0                         NaN                -1    automatic                  1        rfd - rear-wheel drive                5               100  toyota          69             innova         217               2023.0        toyota innova g 2.0 at 2023 car   35830.03930
# 3   74150           imported            1   new car               0          suv               5        0          white                   16          black                    1             5                 5  petrol\t1.8 l         petrol                    3              1.8                         NaN                -1    automatic                  1       fwd - front-wheel drive                4               100  toyota          69      corolla cross         112               2023.0         toyota corolla cross 1.8g 2023   30526.38376
# 4   87573  domestic assembly            0   new car               0    crossover               3        0         silver                   13           gray                   17             5                 8  petrol\t2.0 l         petrol                    3              2.0                         NaN                -1    automatic                  1        rfd - rear-wheel drive                5               100  toyota          69             innova         217               2022.0        toyota innova g 2.0 at 2022 car   34413.03209
# 5   97011  domestic assembly            0   new car               0  van/minivan               8        0          white                   16           gray                   17             5                 2  petrol\t1.0 l         petrol                    3              1.0                         NaN                -1       manual                  3        rfd - rear-wheel drive                5              7100  suzuki          65    super carry van         385               2023.0  suzuki super carry van blind van 2023   12105.29011
# 6  101726  domestic assembly            0   new car               0          suv               5        0          white                   16          black                    1             5                 7  petrol\t1.5 l         petrol                    3              1.5                         NaN                -1    automatic                  1       fwd - front-wheel drive                4               100   honda          27                crv          80               2023.0                   honda crv l 2023 car   39838.14539
# 7  135739           imported            1   new car               0          suv               5        0         copper                    4          black                    1             5                 7  petrol\t2.7 l         petrol                    3              2.7                         NaN                -1    automatic                  1        rfd - rear-wheel drive                5               100  toyota          69           fortuner         166               2023.0       toyota fortuner 2.7l 4x2 at 2023   40485.92011
# 8  142495  domestic assembly            0   new car               0          4x4               0        0           grey                    8          black                    1             4                 5  diesel\t2.2 l         diesel                    0              2.2  single turbo oil injection               583    automatic                  1        rfd - rear-wheel drive                5              7100    ford          22             ranger         336               2023.0       ford ranger xls 2.0l 4x2 at 2023   27854.31303
# 9  143308  domestic assembly            0   new car               0          4x4               0        0          black                    1          black                    1             4                 5  diesel\t2.2 l         diesel                    0              2.2  single turbo oil injection               583    automatic                  1  4wd - four-wheel drive (4wd)                1              7100    ford          22             ranger         336               2023.0       ford ranger xlt 2.0l 4x4 at 2023   33603.31369
# <class 'pandas.DataFrame'>
# RangeIndex: 30652 entries, 0 to 30651
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                30652 non-null  int64
#  1   origin               30652 non-null  str
#  2   origin_code          30652 non-null  int8
#  3   condition            30652 non-null  str
#  4   condition_code       30652 non-null  int8
#  5   car_model            30652 non-null  str
#  6   car_model_code       30652 non-null  int8
#  7   mileage              30652 non-null  Int64
#  8   exterior_color       30652 non-null  str
#  9   exterior_color_code  30652 non-null  int8
#  10  interior_color       30652 non-null  str
#  11  interior_color_code  30652 non-null  int8
#  12  num_of_doors         30652 non-null  Int64
#  13  seating_capacity     30652 non-null  Int64
#  14  engine               30652 non-null  str
#  15  type_of_engine       30652 non-null  str
#  16  type_of_engine_code  30652 non-null  int8
#  17  engine_capacity      29285 non-null  float64
#  18  fuel_system          6742 non-null   str
#  19  fuel_system_code     30652 non-null  int16
#  20  transmission         30652 non-null  str
#  21  transmission_code    30652 non-null  int8
#  22  drive_type           30652 non-null  str
#  23  drive_type_code      30652 non-null  int8
#  24  fuel_consumption     30652 non-null  Int64
#  25  brand                30652 non-null  str
#  26  brand_code           30652 non-null  int8
#  27  grade                30652 non-null  str
#  28  grade_code           30652 non-null  int16
#  29  year_of_manufacture  30620 non-null  float64
#  30  car_name             30652 non-null  str
#  31  price (AUD)          30652 non-null  float64
# dtypes: Int64(4), float64(3), int16(2), int64(1), int8(9), str(13)
# memory usage: 5.4 MB

# %% [markdown]
# ## 1E

# %% [markdown]
# # Data Exploration and Cleaning

# %% [markdown]
# # Data Storage

# %% [markdown]
# # Data Visualisation
